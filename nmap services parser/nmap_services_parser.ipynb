# %%
# Download the nmap-services file
import requests

url: str = 'https://raw.githubusercontent.com/nmap/nmap/master/nmap-services'
response = requests.get(url)

if response.status_code == 200:
    with open('nmap-services', 'wb') as file:
        file.write(response.content)
    print("nmap-services file downloaded successfully.")
else:
    print("Failed to download nmap-services file.")
# Out:
# nmap-services file downloaded successfully.

# %%
# Parse the nmap-services file
DATA_STARTING_LINE: int = 23

portsTCP: list[str] = []
portsUDP: list[str] = []

with open('nmap-services', 'r') as file:
    for i in range(DATA_STARTING_LINE - 1):
        next(file)

    for line in file:
        data: list[str] = line.strip().split()

        if len(data) > 3: 
            data[3] = ' '.join(data[3:])
            data = data[:4]
            data[3] = data[3][2:]

        if len(data) < 4: 
            data.append('')

        if data[1].endswith('/tcp'):
            data[1] = int(data[1][:-4])
            data[2] = float(data[2])
            portsTCP.append(data)
        elif data[1].endswith('/udp'):
            data[1] = int(data[1][:-4])
            data[2] = float(data[2])
            portsUDP.append(data)

print(f'Length: {len(portsTCP)} -> {portsTCP}')
print(f'Length: {len(portsUDP)} -> {portsUDP}')
# Out:
# Length: 8380 -> [['tcpmux', 1, 0.001995, 'TCP Port Service Multiplexer'], ['compressnet', 2, 1.3e-05, 'Management Utility'], ['compressnet', 3, 0.001242, 'Compression Process'], ['unknown', 4, 0.000477, ''], ['rje', 5, 0.0, 'Remote Job Entry'], ['unknown', 6, 0.000502, ''], ['echo', 7, 0.004855, ''], ['unknown', 8, 1.3e-05, ''], ['discard', 9, 0.003764, 'sink null'], ['unknown', 10, 6.3e-05, ''], ['systat', 11, 7.5e-05, 'Active Users'], ['unknown', 12, 6.3e-05, ''], ['daytime', 13, 0.003927, ''], ['unknown', 14, 3.8e-05, ''], ['netstat', 15, 3.8e-05, ''], ['unknown', 16, 5e-05, ''], ['qotd', 17, 0.002346, 'Quote of the Day'], ['msp', 18, 0.0, 'Message Send Protocol'], ['chargen', 19, 0.002559, 'ttytst source Character Generator'], ['ftp-data', 20, 0.001079, 'File Transfer [Default Data]'], ['ftp', 21, 0.197667, 'File Transfer [Control]'], ['ssh', 22, 0.182286, 'Secure Shell Login'], ['telnet', 23, 0.221265, ''], ['priv-mail', 24, 0.001154, 'any private mail system'], ['smtp', 25, 0.131314, 'Simple Mail Transfer'], ['rsftp', 26, 0.007991, ''], ['nsw-fe', 27, 0.000138, 'NSW User System FE'], ['unknown', 28, 5e-05, ''], ['msg-icp', 29, 2.5e-05, 'MSG ICP'], ['unknown', 30, 0.000527, ''], ['msg-auth', 31, 2.5e-05, 'MSG Authentication'], ['unknown', 32, 0.000339, ''], ['dsp', 33, 0.001016, 'Display Support Protocol'], ['unknown', 34, 2.5e-05, ''], ['priv-print', 35, 3.8e-05, 'any private printer server'], ['time', 37, 0.003161, 'timserver'], ['rap', 38, 2.5e-05, 'Route Access Protocol'], ['rlp', 39, 0.0, 'Resource Location Protocol'], ['unknown', 40, 3.8e-05, ''], ['graphics', 41, 0.0, ''], ['nameserver', 42, 0.000803, 'name | Host Name Server'], ['whois', 43, 0.000314, 'nicname | Who Is'], ['mpm-flags', 44, 2.5e-05, 'MPM FLAGS Protocol'], ['mpm', 45, 5e-05, 'Message Processing Module [recv]'], ['mpm-snd', 46, 0.0, 'MPM [default send]'], ['ni-ftp', 47, 7.5e-05, 'NI FTP'], ['auditd', 48, 1.3e-05, 'Digital Audit Daemon'], ['tacacs', 49, 0.000665, 'Login Host Protocol (TACACS)'], ['re-mail-ck', 50, 5e-05, 'Remote Mail Checking Protocol'], ['la-maint', 51, 3.8e-05, 'IMP Logical Address Maintenance'], ['xns-time', 52, 6.3e-05, 'XNS Time Protocol'], ['domain', 53, 0.048463, 'Domain Name Server'], ['xns-ch', 54, 1.3e-05, 'XNS Clearinghouse'], ['isi-gl', 55, 0.000125, 'ISI Graphics Language'], ['xns-auth', 56, 1.3e-05, 'XNS Authentication'], ['priv-term', 57, 0.000125, 'any private terminal access'], ['xns-mail', 58, 2.5e-05, 'XNS Mail'], ['priv-file', 59, 8.8e-05, 'any private file service'], ['unknown', 60, 3.8e-05, ''], ['ni-mail', 61, 0.0, 'NI MAIL'], ['acas', 62, 0.0, 'ACA Services'], ['via-ftp', 63, 0.0, 'whoispp | VIA Systems - FTP & whois++ | whois++'], ['covia', 64, 0.0, 'Communications Integrator (CI)'], ['tacacs-ds', 65, 1.3e-05, 'TACACS-Database Service'], ['sqlnet', 66, 7.5e-05, 'sql*net | sql-net | Oracle SQL*NET'], ['dhcps', 67, 1.3e-05, 'bootps | DHCP/Bootstrap Protocol Server | Bootstrap Protocol Server'], ['dhcpc', 68, 6.3e-05, 'bootpc | DHCP/Bootstrap Protocol Client | Bootstrap Protocol Client'], ['tftp', 69, 3.8e-05, 'Trivial File Transfer'], ['gopher', 70, 0.000226, ''], ['netrjs-1', 71, 2.5e-05, 'Remote Job Service'], ['netrjs-2', 72, 1.3e-05, 'Remote Job Service'], ['netrjs-3', 73, 2.5e-05, 'Remote Job Service'], ['netrjs-4', 74, 2.5e-05, 'Remote Job Service'], ['priv-dial', 75, 6.3e-05, 'any private dial out service'], ['deos', 76, 6.3e-05, 'Distributed External Object Store'], ['priv-rje', 77, 0.000113, 'any private RJE service, netrjs'], ['vettcp', 78, 0.0, ''], ['finger', 79, 0.006022, ''], ['http', 80, 0.484143, 'World Wide Web HTTP'], ['hosts2-ns', 81, 0.012056, 'HOSTS2 Name Server'], ['xfer', 82, 0.002923, 'XFER Utility'], ['mit-ml-dev', 83, 0.000539, 'MIT ML Device'], ['ctf', 84, 0.000276, 'Common Trace Facility'], ['mit-ml-dev', 85, 0.00069, 'MIT ML Device'], ['mfcobol', 86, 0.000138, 'Micro Focus Cobol'], ['priv-term-l', 87, 0.000125, 'any private terminal link, ttylink'], ['kerberos-sec', 88, 0.006072, 'ke ...
# Length: 19022 -> [['tcpmux', 1, 0.001236, 'TCP Port Service Multiplexer'], ['compressnet', 2, 0.001845, 'Management Utility'], ['compressnet', 3, 0.001532, 'Compression Process'], ['rje', 5, 0.000593, 'Remote Job Entry'], ['echo', 7, 0.024679, ''], ['discard', 9, 0.015733, 'sink null'], ['systat', 11, 0.000577, 'Active Users'], ['daytime', 13, 0.004827, ''], ['qotd', 17, 0.009209, 'Quote of the Day'], ['msp', 18, 0.00061, 'Message Send Protocol'], ['chargen', 19, 0.015865, 'ttytst source Character Generator'], ['ftp-data', 20, 0.001878, 'File Transfer [Default Data]'], ['ftp', 21, 0.004844, 'File Transfer [Control]'], ['ssh', 22, 0.003905, 'Secure Shell Login'], ['telnet', 23, 0.006211, ''], ['priv-mail', 24, 0.000329, 'any private mail system'], ['smtp', 25, 0.001285, 'Simple Mail Transfer'], ['nsw-fe', 27, 0.000395, 'NSW User System FE'], ['msg-icp', 29, 0.00056, 'MSG ICP'], ['msg-auth', 31, 0.000939, 'MSG Authentication'], ['dsp', 33, 0.00056, 'Display Support Protocol'], ['priv-print', 35, 0.000708, 'any private printer server'], ['time', 37, 0.006458, 'timserver'], ['rap', 38, 0.002043, 'Route Access Protocol'], ['rlp', 39, 0.000478, 'Resource Location Protocol'], ['graphics', 41, 0.000445, ''], ['nameserver', 42, 0.005288, 'Host Name Server'], ['whois', 43, 0.000313, 'nicname'], ['mpm-flags', 44, 0.000659, 'MPM FLAGS Protocol'], ['mpm', 45, 0.000741, 'Message Processing Module [recv]'], ['mpm-snd', 46, 0.000494, 'MPM [default send]'], ['ni-ftp', 47, 0.001071, 'NI FTP'], ['auditd', 48, 0.000708, 'Digital Audit Daemon'], ['tacacs', 49, 0.01402, 'Login Host Protocol (TACACS)'], ['re-mail-ck', 50, 0.000428, 'Remote Mail Checking Protocol'], ['la-maint', 51, 0.00028, 'IMP Logical Address Maintenance'], ['xns-time', 52, 0.000362, 'XNS Time Protocol'], ['domain', 53, 0.213496, 'Domain Name Server'], ['xns-ch', 54, 0.000659, 'XNS Clearinghouse'], ['isi-gl', 55, 0.000478, 'ISI Graphics Language'], ['xns-auth', 56, 0.001285, 'XNS Authentication'], ['priv-term', 57, 0.000774, 'any private terminal access'], ['xns-mail', 58, 0.000428, 'XNS Mail'], ['priv-file', 59, 0.000478, 'any private file service'], ['ni-mail', 61, 0.000461, 'NI MAIL'], ['acas', 62, 0.000264, 'ACA Services'], ['via-ftp', 63, 0.000445, 'VIA Systems - FTP & whois++'], ['covia', 64, 0.000593, 'Communications Integrator (CI)'], ['tacacs-ds', 65, 0.000741, 'TACACS-Database Service'], ['sqlnet', 66, 0.000544, 'Oracle SQL*NET'], ['dhcps', 67, 0.22801, 'DHCP/Bootstrap Protocol Server'], ['dhcpc', 68, 0.140118, 'DHCP/Bootstrap Protocol Client'], ['tftp', 69, 0.102835, 'Trivial File Transfer'], ['gopher', 70, 0.000544, ''], ['netrjs-1', 71, 0.00056, 'Remote Job Service'], ['netrjs-2', 72, 0.000494, 'Remote Job Service'], ['netrjs-3', 73, 0.000428, 'Remote Job Service'], ['netrjs-4', 74, 0.000478, 'Remote Job Service'], ['priv-dial', 75, 0.000577, 'any private dial out service'], ['deos', 76, 0.000675, 'Distributed External Object Store'], ['priv-rje', 77, 0.000741, 'any private RJE service, netjrs'], ['vettcp', 78, 0.000626, ''], ['finger', 79, 0.000956, ''], ['http', 80, 0.035767, 'World Wide Web HTTP'], ['hosts2-ns', 81, 0.001005, 'HOSTS2 Name Server'], ['xfer', 82, 0.000659, 'XFER Utility'], ['mit-ml-dev', 83, 0.001203, 'MIT ML Device'], ['ctf', 84, 0.00061, 'Common Trace Facility'], ['mit-ml-dev', 85, 0.00061, 'MIT ML Device'], ['mfcobol', 86, 0.000824, 'Micro Focus Cobol'], ['kerberos-sec', 88, 0.013476, 'Kerberos (v5)'], ['su-mit-tg', 89, 0.000494, 'SU/MIT Telnet Gateway'], ['dnsix', 90, 0.000511, 'DNSIX Securit Attribute Token Map'], ['mit-dov', 91, 0.000478, 'MIT Dover Spooler'], ['npp', 92, 0.000478, 'Network Printing Protocol'], ['dcp', 93, 0.000774, 'Device Control Protocol'], ['objcall', 94, 0.000428, 'Tivoli Object Dispatcher'], ['supdup', 95, 0.000379, ''], ['dixie', 96, 0.000939, 'DIXIE Protocol Specification'], ['swift-rvf', 97, 0.000362, 'Swift Remote Virtural File Protocol'], ['tacnews', 98, 0.00056, 'TAC News'], ['metagram', 99, 0.000972, 'Metagram Rela ...

# %%
# Save the nmap-services data into a JSON file
import json

jsonData: dict[str, list[dict]] = {
    'tcp': [],
    'udp': []
}

for port in portsTCP:
    data: dict = {
        'service name': port[0],
        'port': port[1],
        'frequency': port[2],
        'comment': port[3]
    }
    jsonData['tcp'].append(data)

for port in portsUDP:
    data: dict = {
        'service name': port[0],
        'port': port[1],
        'frequency': port[2],
        'comment': port[3]
    }
    jsonData['udp'].append(data)

jsonData['tcp'].sort(key=lambda x: x['frequency'], reverse=True)
jsonData['udp'].sort(key=lambda x: x['frequency'], reverse=True)

with open('nmap-services.json', 'w') as jsonFile:
    json.dump(jsonData, jsonFile, indent=4)

print('JSON data has been written to nmap-services.json')
# Out:
# JSON data has been written to nmap-services.json
